# %%
class admiss_form:
    # property of class
    name = None
    course = None
    contact = None
    enquiry = None
    enterance_exam = "Have you taken any Entrence exam to qualify Scholarship"
    parents_no = 1

# %%
tom = admiss_form()

# %%
tom.name = "Tom"
tom.course = "ETL"
tom.contact = "9898989898"
tom.enquiry = "What other courses offer"
tom.enterance_exam()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 5
#       3 tom.contact = "9898989898"
#       4 tom.enquiry = "What other courses offer"
# ----> 5 tom.enterance_exam()
#
# TypeError: 'str' object is not callable
