# %%
a = [1,5,3,8,2,3,4,0,6,11,22,8,34,87,1,8]
print ("A List:",a)

b = [2,4,6,8]
print ("B List:",b)

c = [100]
print ("C List:",c)
# Out:
# A List: [1, 5, 3, 8, 2, 3, 4, 0, 6, 11, 22, 8, 34, 87, 1, 8]
# B List: [2, 4, 6, 8]
# C List: [100]

# %% [raw]
# '''
# append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort'
# '''

# %%
# Append
''' Adding new data inside list '''
a.append('A')

# %%
a
# Out:
# [1, 5, 3, 8, 2, 3, 4, 0, 6, 11, 22, 8, 34, 87, 1, 8, 'A']

# %%
a[0] = 100

# %%
a
# Out:
# [100, 1, 1, 2, 3, 3, 4, 5, 6, 8, 8, 8, 11, 22, 34, 87, 'A']

# %%
a[3] = "April"

# %%
a
# Out:
# [100, 1, 1, 'April', 3, 3, 4, 5, 6, 8, 8, 8, 11, 22, 34, 87, 'A']

# %%
a.clear()

# %%
a
# Out:
# []

# %%
fruits = ["Apple", "mango", "Grapes", "Orange", "Salad", "Cookies"]

# %%
fruits.index("mango")
# Out:
# 1

# %%
for fruit in fruits:
    print(f"Index of fruit is {fruit}:\t{fruits.index(fruit)}")
# Out:
# Index of fruit is Apple:	0
# Index of fruit is mango:	1
# Index of fruit is Grapes:	2
# Index of fruit is Orange:	3
# Index of fruit is Salad:	4
# Index of fruit is Cookies:	5

# %%
fruits.append("cake")

# %%
fruits
# Out:
# ['Apple',
#  'mango',
#  'Grapes',
#  'Orange',
#  'Salad',
#  'Cookies',
#  'cake',
#  'Strawberry']

# %%
fruits.append("Strawberry")

# %%
test = input("Enter fruits names")

if [test] in fruits:
    print ("Not there")
else :
    print ("Item Present")
# Out:
# Enter fruits names pen
# Item Present

# %%
test = input("Enter fruits names")
# Out:
# Enter fruits names Apple
