# %%
x = [1,2,3,4,5,6]

# %%
type(x)
# Out:
# list

# %%
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
print(x)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
x.append(6)

# %%
print (x)
# Out:
# [1, 2, 3, 4, 5, 6, 6]

# %%
x.copy()
# Out:
# [1, 2, 3, 4, 5, 6, 6]

# %%
x.count(1)
x.count(6)
# Out:
# 2

# %%
x.index(1)
# Out:
# 0

# %%
n1 = x.index(6)
n2 = x.index(5)


print ("Index vaue of x in index in 6th pos ", n1)
print ("Index vaue of x in index in 5th pos ", n2)
# Out:
# Index vaue of x in index in 6th pos  5
# Index vaue of x in index in 5th pos  4

# %%
x.append(100)
x.append(200)

# %%
x.append(19)

# %%
print(x)
# Out:
# [1, 2, 3, 4, 5, 6, 6, 100, 100, 100, 200, 100, 100, 200, 19]

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 x.sort()
#
# AttributeError: 'NoneType' object has no attribute 'sort'

# %%
x = x.sort()

# %%
L1 = [2,3,4,5,6,0,11,1]

# %%
L1.sort()

# %%
sorted_list = L1.sort()

print (sorted_list)
# Out:
# None

# %%
cars = ['Ford', 'BMW', 'Volvo']

cars.sort()

# %%
print(cars)
# Out:
# ['BMW', 'Ford', 'Volvo']
