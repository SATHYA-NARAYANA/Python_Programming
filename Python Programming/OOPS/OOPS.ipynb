# %%
class Feedback():
    name = None
    Comments  = None

    def ratings(self):
         print("... sending ratings")

# %%
class visitingform():
    name = None
    age  = None

    def send_sms(self):
         print("sending sms")

    def greetings(b):
        print("Hello Welcome to Cloud")

# %%
tom = visitingform()
jack = visitingform ()

tom = Feedback()

# %%
type(tom)

# %%
id(tom)

# %%
print(tom.name)

# %%
tom.name = "tom"
tom.age = 25

# %%
tom

# %%
tom.name

# %%
dir(tom)

# %%
tom.__dict__

# %%
dir(str)

# %%
dir(print)

# %%
tom.send_sms()

# %%
# by default we need to specify self as first argument
tom.send_sms()

# %%
class test:
    name = None
    age  = None
    phone = None

    def send_sms():
        print('....send sms')

# %%
class test2:
    name = None
    age  = None
    phone = None

    def send_sms():
        print('....send sms')

# %%
tom = test()

# %%
jack = test()

# %%
tom is not jack
# Out:
# True

# %%
tom.name = "Tom"

# %%
jack.name = "jack"
dir(jack)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'age',
#  'greetings',
#  'name',
#  'send_sms']

# %%
dir(jack)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'age',
#  'greetings',
#  'name',
#  'send_sms']

# %%
dir(tom)
# Out:
# ['Comments',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'name',
#  'ratings']

# %%
jack.
