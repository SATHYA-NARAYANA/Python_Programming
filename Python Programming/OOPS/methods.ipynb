# %%
class admiss_form:
    # property of class
    name = None
    phone = None
    enquiry = None

# %%
tom = admiss_form()

# %%
tom.name = "Tom"
tom.phone = "9898989898"
tom.enquiry = "What other courses offer"

# %%
tom.phone

# %%
tom.name

# %%
new_joinee = input (f"Enter your course{.co}")

# %%
    course = input(f"Enter a name (default is {tom.course}): ") or tom.course

# %%
x = input(f"{tom.course}")

# %%
class Student:
    name = "Tom"
    course = None
    contact = None
    contact = None
    enquiry = "What other courses offer"
    entrance_exam = ""
    
    def __init__(self,name,course,contact,enquiry,enterance_exam):
        self.name = name
        self.course = course
        self.contact = contact
        self.enquiry = enquiry
        self.entrance_exam = entrance_exam

# %%
class admiss_form:
    # property of class
    name = None
    phone = None
    enquiry = None

    def setphone(self,myphone):
        if len(str(myphone)) == 10:
            self.phone = myphone
            print("Valid phone no")

        else:
            print("Invalid contact no...")
    def getphone(self):
        return self.phone

# %%
tom.phone = 1234567

# %%
tom.__dict__
# Out:
# {'phone': 1234567}

# %%
tom.setphone =(123456788)
