# %%
tech_stack = {
     "Configuration":"Ansible",
     "Container":"CRIO",
     "Cloud Computing":"AWS",
     "Scripting":"Python", 
     "Monitering":"Cloud Watch"
      
    
}

# %%
x = tech_stack["Monitering"]

# %%
print(x)
# Out:
# Cloud Watch

# %%
for tech, course in tech_stack.items():
    print(f'Your loved {tech}: course matches with {course}')
# Out:
# Your loved Configuration: course matches with Ansible
# Your loved Container: course matches with CRIO
# Your loved Cloud Computing: course matches with AWS
# Your loved Scripting: course matches with Python
# Your loved Monitering: course matches with Cloud Watch

# %%
print("Do you like to suggest / recommend some more tech stack")
new_course_suggestion = []
# Out:
# Do you like to suggest / recommend some more tech stack

# %%
while True:
    new_tech_stack = input("Enter Tech stack name:")
    if new_tech_stack == 'Done':
        break

    if new_tech_stack not in tech_stack:
        new_course_suggestion.append(new_tech_stack)
        print(f"{new_tech_stack} reccomeded succesfully.")
# Out:
# Enter Tech stack name: ETL
# ETL reccomeded succesfully.
# Enter Tech stack name: Devops
# Devops reccomeded succesfully.
# Enter Tech stack name: Done

# %%
print(tech_stack)
# Out:
# {'Configuration': 'Ansible', 'Container': 'CRIO', 'Cloud Computing': 'AWS', 'Scripting': 'Python', 'Monitering': 'Cloud Watch'}

# %%
print("Do you like to suggest / recommend some more tech stack")
new_course_suggestion = {}
# Out:
# Do you like to suggest / recommend some more tech stack
