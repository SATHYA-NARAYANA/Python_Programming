# %%
tech_stack = {
     "Configuration":"Ansible",
     "Container":"CRIO",
     "Cloud Computing":"AWS",
     "Scripting":"Python", 
     "Monitering":"Cloud Watch"
      
    
}

# %%
x = tech_stack["Monitering"]

# %%
print(x)
# Out:
# Cloud Watch

# %%
for tech, course in tech_stack.items():
    print(f'Your loved {tech}: course matches with {course}{.upper()}')
# Out:
# Your loved Configuration: course matches with Ansible.upper()
# Your loved Container: course matches with CRIO.upper()
# Your loved Cloud Computing: course matches with AWS.upper()
# Your loved Scripting: course matches with Python.upper()
# Your loved Monitering: course matches with Cloud Watch.upper()
