# %%
orders = ['Order#001', 'Order#002', 'Order#003','Order#004', 'Order#005', 'Order#006','Order#007', 'Order#008', 'Order#009']
for order in orders:
    print(f"Generating label for {order}")
# Out:
# Generating label for Order#001
# Generating label for Order#002
# Generating label for Order#003
# Generating label for Order#004
# Generating label for Order#005
# Generating label for Order#006
# Generating label for Order#007
# Generating label for Order#008
# Generating label for Order#009

# %%
statuses = ['Pending', 'Shipped', 'Delivered']
for status in statuses:
    print(f"Current status: {status}")
